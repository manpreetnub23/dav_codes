# %%
import pandas as pd

# %%
dic = {'Name':['Mudit Chauhan','Seema Chopra','Rani Gupta','Aditya Narayan','Sanjeev Sahni','Prakash Kumar','Ritu Agarwal','Akshay Goel','Meeta Kulkarni','Preeti Ahuja','Sunil Das Gupta','Sonali Sapre','Rashmi Talwar','Ashish Dubey','Kiran Sharma','Sameer Bansal'],
      'Birth_Month':['December','January','March','October','February','December','September','August','July','November','April','January','June','May','February','October'],
      'Gender':['M','F','F','M','M','M','F','M','F','F','M','F','F','M','F','M'],
      'Pass_Division':['3','2','1','1','2','3','1','1','2','2','3','1','3','2','2','1']}
df = pd.DataFrame(dic)
display(df)
# Out:
#                Name Birth_Month Gender Pass_Division
# 0     Mudit Chauhan    December      M             3
# 1      Seema Chopra     January      F             2
# 2        Rani Gupta       March      F             1
# 3    Aditya Narayan     October      M             1
# 4     Sanjeev Sahni    February      M             2
# 5     Prakash Kumar    December      M             3
# 6      Ritu Agarwal   September      F             1
# 7       Akshay Goel      August      M             1
# 8    Meeta Kulkarni        July      F             2
# 9      Preeti Ahuja    November      F             2
# 10  Sunil Das Gupta       April      M             3
# 11     Sonali Sapre     January      F             1
# 12    Rashmi Talwar        June      F             3
# 13     Ashish Dubey         May      M             2
# 14     Kiran Sharma    February      F             2
# 15    Sameer Bansal     October      M             1

# %%
ohedata = pd.get_dummies(df,columns=['Gender','Pass_Division']) 
display(ohedata)
# Out:
#                Name Birth_Month  Gender_F  Gender_M  Pass_Division_1  \
# 0     Mudit Chauhan    December     False      True            False
# 1      Seema Chopra     January      True     False            False
# 2        Rani Gupta       March      True     False             True
# 3    Aditya Narayan     October     False      True             True
# 4     Sanjeev Sahni    February     False      True            False
# 5     Prakash Kumar    December     False      True            False
# 6      Ritu Agarwal   September      True     False             True
# 7       Akshay Goel      August     False      True             True
# 8    Meeta Kulkarni        July      True     False            False
# 9      Preeti Ahuja    November      True     False            False
# 10  Sunil Das Gupta       April     False      True            False
# 11     Sonali Sapre     January      True     False             True
# 12    Rashmi Talwar        June      True     False            False
# ...

# %%
df['Birth_Month'] = df['Birth_Month'].astype('category')
display(df)
# Out:
#                Name Birth_Month Gender Pass_Division
# 0     Mudit Chauhan    December      M             3
# 1      Seema Chopra     January      F             2
# 2        Rani Gupta       March      F             1
# 3    Aditya Narayan     October      M             1
# 4     Sanjeev Sahni    February      M             2
# 5     Prakash Kumar    December      M             3
# 6      Ritu Agarwal   September      F             1
# 7       Akshay Goel      August      M             1
# 8    Meeta Kulkarni        July      F             2
# 9      Preeti Ahuja    November      F             2
# 10  Sunil Das Gupta       April      M             3
# 11     Sonali Sapre     January      F             1
# 12    Rashmi Talwar        June      F             3
# 13     Ashish Dubey         May      M             2
# 14     Kiran Sharma    February      F             2
# 15    Sameer Bansal     October      M             1

# %%
display(df.sort_values('Birth_Month'))
# Out:
#                Name Birth_Month Gender Pass_Division
# 10  Sunil Das Gupta       April      M             3
# 7       Akshay Goel      August      M             1
# 0     Mudit Chauhan    December      M             3
# 5     Prakash Kumar    December      M             3
# 4     Sanjeev Sahni    February      M             2
# 14     Kiran Sharma    February      F             2
# 1      Seema Chopra     January      F             2
# 11     Sonali Sapre     January      F             1
# 8    Meeta Kulkarni        July      F             2
# 12    Rashmi Talwar        June      F             3
# 2        Rani Gupta       March      F             1
# 13     Ashish Dubey         May      M             2
# 9      Preeti Ahuja    November      F             2
# 3    Aditya Narayan     October      M             1
# 15    Sameer Bansal     October      M             1
# 6      Ritu Agarwal   September      F             1
