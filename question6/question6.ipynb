# %%
import pandas as pd

# %%
df = pd.read_csv('C://Users//Prabhjot Khatri//Desktop//PythonPrac//weather dataset//weatherHistory.csv')
df.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                     251          15.8263           0               1015.13
# ...

# %%
#a
df.groupby('Precip Type')['Temperature (C)'].mean()
# Out:
# Precip Type
# rain    13.852989
# snow    -3.270885
# Name: Temperature (C), dtype: float64

# %%
#b
df['Formatted Date'] = pd.to_datetime(df['Formatted Date'],utc=True)
df = df.drop_duplicates(['Formatted Date'])
display(df)
# Out:
#                  Formatted Date        Summary Precip Type  Temperature (C)  \
# 0     2006-03-31 22:00:00+00:00  Partly Cloudy        rain         9.472222
# 1     2006-03-31 23:00:00+00:00  Partly Cloudy        rain         9.355556
# 2     2006-04-01 00:00:00+00:00  Mostly Cloudy        rain         9.377778
# 3     2006-04-01 01:00:00+00:00  Partly Cloudy        rain         8.288889
# 4     2006-04-01 02:00:00+00:00  Mostly Cloudy        rain         8.755556
# ...                         ...            ...         ...              ...
# 96448 2016-09-09 17:00:00+00:00  Partly Cloudy        rain        26.016667
# 96449 2016-09-09 18:00:00+00:00  Partly Cloudy        rain        24.583333
# 96450 2016-09-09 19:00:00+00:00  Partly Cloudy        rain        22.038889
# 96451 2016-09-09 20:00:00+00:00  Partly Cloudy        rain        21.522222
# 96452 2016-09-09 21:00:00+00:00  Partly Cloudy        rain        20.438889
#
# ...

# %%
df.index = pd.to_datetime(df['Formatted Date'])
print(df.index)
# Out:
# DatetimeIndex(['2006-03-31 22:00:00+00:00', '2006-03-31 23:00:00+00:00',
#                '2006-04-01 00:00:00+00:00', '2006-04-01 01:00:00+00:00',
#                '2006-04-01 02:00:00+00:00', '2006-04-01 03:00:00+00:00',
#                '2006-04-01 04:00:00+00:00', '2006-04-01 05:00:00+00:00',
#                '2006-04-01 06:00:00+00:00', '2006-04-01 07:00:00+00:00',
#                ...
#                '2016-09-09 12:00:00+00:00', '2016-09-09 13:00:00+00:00',
#                '2016-09-09 14:00:00+00:00', '2016-09-09 15:00:00+00:00',
#                '2016-09-09 16:00:00+00:00', '2016-09-09 17:00:00+00:00',
#                '2016-09-09 18:00:00+00:00', '2016-09-09 19:00:00+00:00',
#                '2016-09-09 20:00:00+00:00', '2016-09-09 21:00:00+00:00'],
#               dtype='datetime64[ns, UTC]', name='Formatted Date', length=96429, freq=None)

# %%
df.head()
# Out:
#                                      Formatted Date        Summary  \
# Formatted Date
# 2006-03-31 22:00:00+00:00 2006-03-31 22:00:00+00:00  Partly Cloudy
# 2006-03-31 23:00:00+00:00 2006-03-31 23:00:00+00:00  Partly Cloudy
# 2006-04-01 00:00:00+00:00 2006-04-01 00:00:00+00:00  Mostly Cloudy
# 2006-04-01 01:00:00+00:00 2006-04-01 01:00:00+00:00  Partly Cloudy
# 2006-04-01 02:00:00+00:00 2006-04-01 02:00:00+00:00  Mostly Cloudy
#
#                           Precip Type  Temperature (C)  \
# Formatted Date
# 2006-03-31 22:00:00+00:00        rain         9.472222
# 2006-03-31 23:00:00+00:00        rain         9.355556
# 2006-04-01 00:00:00+00:00        rain         9.377778
# 2006-04-01 01:00:00+00:00        rain         8.288889
# 2006-04-01 02:00:00+00:00        rain         8.755556
#
#                            Apparent Temperature (C)  Humidity  \
# Formatted Date
# 2006-03-31 22:00:00+00:00                  7.388889      0.89
# ...

# %%
df.asfreq('20min').ffill()
# Out:
#                                      Formatted Date        Summary  \
# Formatted Date
# 2005-12-31 23:00:00+00:00 2005-12-31 23:00:00+00:00  Partly Cloudy
# 2005-12-31 23:20:00+00:00 2005-12-31 23:00:00+00:00  Partly Cloudy
# 2005-12-31 23:40:00+00:00 2005-12-31 23:00:00+00:00  Partly Cloudy
# 2006-01-01 00:00:00+00:00 2006-01-01 00:00:00+00:00  Mostly Cloudy
# 2006-01-01 00:20:00+00:00 2006-01-01 00:00:00+00:00  Mostly Cloudy
# ...                                             ...            ...
# 2016-12-31 20:40:00+00:00 2016-12-31 20:00:00+00:00  Mostly Cloudy
# 2016-12-31 21:00:00+00:00 2016-12-31 21:00:00+00:00  Mostly Cloudy
# 2016-12-31 21:20:00+00:00 2016-12-31 21:00:00+00:00  Mostly Cloudy
# 2016-12-31 21:40:00+00:00 2016-12-31 21:00:00+00:00  Mostly Cloudy
# 2016-12-31 22:00:00+00:00 2016-12-31 22:00:00+00:00  Mostly Cloudy
#
#                           Precip Type  Temperature (C)  \
# Formatted Date
# 2005-12-31 23:00:00+00:00        rain         0.577778
# ...

# %%
#c
df['New'] = pd.to_datetime(df['Formatted Date']).dt.strftime('%Y-%m')
df['New'] = pd.to_datetime(df['New'])
df['New']
# Out:
# Formatted Date
# 2006-03-31 22:00:00+00:00   2006-03-01
# 2006-03-31 23:00:00+00:00   2006-03-01
# 2006-04-01 00:00:00+00:00   2006-04-01
# 2006-04-01 01:00:00+00:00   2006-04-01
# 2006-04-01 02:00:00+00:00   2006-04-01
#                                ...
# 2016-09-09 17:00:00+00:00   2016-09-01
# 2016-09-09 18:00:00+00:00   2016-09-01
# 2016-09-09 19:00:00+00:00   2016-09-01
# 2016-09-09 20:00:00+00:00   2016-09-01
# 2016-09-09 21:00:00+00:00   2016-09-01
# Name: New, Length: 96429, dtype: datetime64[ns]

# %%
df['New'].apply(lambda x: x.replace(day = 15))
# Out:
# Formatted Date
# 2006-03-31 22:00:00+00:00   2006-03-15
# 2006-03-31 23:00:00+00:00   2006-03-15
# 2006-04-01 00:00:00+00:00   2006-04-15
# 2006-04-01 01:00:00+00:00   2006-04-15
# 2006-04-01 02:00:00+00:00   2006-04-15
#                                ...
# 2016-09-09 17:00:00+00:00   2016-09-15
# 2016-09-09 18:00:00+00:00   2016-09-15
# 2016-09-09 19:00:00+00:00   2016-09-15
# 2016-09-09 20:00:00+00:00   2016-09-15
# 2016-09-09 21:00:00+00:00   2016-09-15
# Name: New, Length: 96429, dtype: datetime64[ns]

# %%
#d
dfnew = df.groupby(['Summary', 'Precip Type']).agg({'Pressure (millibars)' : 'mean'})
dfnew['Pressure (millibars)'].groupby(level = 0, group_keys=False).nlargest()
# Out:
# Summary                              Precip Type
# Breezy                               rain            652.073810
#                                      snow            255.370833
# Breezy and Dry                       rain           1021.600000
# Breezy and Foggy                     snow           1009.389259
#                                      rain           1007.397500
# Breezy and Mostly Cloudy             snow           1021.541923
#                                      rain            999.513000
# Breezy and Overcast                  snow           1017.579821
#                                      rain           1000.280106
# Breezy and Partly Cloudy             snow           1026.797143
#                                      rain            995.836755
# Clear                                rain            952.322923
#                                      snow            940.489332
# Dangerously Windy and Partly Cloudy  rain           1009.050000
# ...

# %%
print(pd.cut(df['Wind Speed (km/h)'],3))
grp = df.groupby(['Summary',pd.cut(df['Wind Speed (km/h)'],3)])
res = grp.size().unstack()
res
# Out:
# Formatted Date
# 2006-03-31 22:00:00+00:00    (-0.0639, 21.284]
# 2006-03-31 23:00:00+00:00    (-0.0639, 21.284]
# 2006-04-01 00:00:00+00:00    (-0.0639, 21.284]
# 2006-04-01 01:00:00+00:00    (-0.0639, 21.284]
# 2006-04-01 02:00:00+00:00    (-0.0639, 21.284]
#                                    ...
# 2016-09-09 17:00:00+00:00    (-0.0639, 21.284]
# 2016-09-09 18:00:00+00:00    (-0.0639, 21.284]
# 2016-09-09 19:00:00+00:00    (-0.0639, 21.284]
# 2016-09-09 20:00:00+00:00    (-0.0639, 21.284]
# 2016-09-09 21:00:00+00:00    (-0.0639, 21.284]
# Name: Wind Speed (km/h), Length: 96429, dtype: category
# Categories (3, interval[float64, right]): [(-0.0639, 21.284] < (21.284, 42.568] < (42.568, 63.853]]
# ...
