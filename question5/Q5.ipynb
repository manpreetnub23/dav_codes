# %%
from sklearn import datasets
import pandas as pd
import seaborn

# %%
iris = datasets.load_iris()
print(iris.target_names)
df = pd.DataFrame(iris.data,columns=['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)'])
# Out:
# ['setosa' 'versicolor' 'virginica']

# %%
print(df)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
df['Species'] = iris.target

# %%
df.Species.replace([0,1,2],['setosa','versicolor','virginica'],inplace=True)
display(df)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#        Species
# 0       setosa
# ...

# %%
df['Species'].value_counts().plot(kind='bar',title='Iris Species Distribution',color=['g','b','r'])
# Out:
# <Axes: title={'center': 'Iris Species Distribution'}, xlabel='Species'>

# %%
df.plot(x='petal width (cm)',y='sepal width (cm)',kind='scatter',title='Petal width Vs Sepal width')
# Out:
# <Axes: title={'center': 'Petal width Vs Sepal width'}, xlabel='petal width (cm)', ylabel='sepal width (cm)'>

# %%
df['petal length (cm)'].plot.density(color=['g','r','b','y'])
# Out:
# <Axes: ylabel='Density'>
